# %%
import nibabel as nib

bold_path = "/Users/andreaknoepffler/Documents/github/junkyard/data/func/sub-001_task-skewedGamblingTask_bold.nii.gz"
img = nib.load(bold_path)

print(img)
print("Shape:", img.shape)
print("Affine:\n", img.affine)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (80, 80, 46, 442)
# affine:
# [[ -2.9000001    0.           0.         114.55000305]
#  [  0.          -2.9000001    0.         114.55000305]
#  [  0.           0.           2.9000001  -22.04129982]
#  [  0.           0.           0.           1.        ]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'')
# dim_info        : 57
# dim             : [  4  80  80  46 442   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.  2.9 2.9 2.9 2.  1.  1.  1. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 45
# slice_code      : alternating increasing
# ...

# %%
import nilearn
from nilearn.plotting import plot_epi, show
from nilearn import image
mean_image = image.mean_img(img)

plot_epi(mean_image, title="Mean EPI")
show()
